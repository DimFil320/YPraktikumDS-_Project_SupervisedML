# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Привет Дмитрий! Меня зовут Марат, и я буду твоим ревьюером.  По поводу обращения - в IT сфере принято общаться на «ты» :) Но, если привычней на «вы», дай знать. Как ревьюера моя задача помочь тебе в развитии, дав хорошие советы. Я внимательно посмотрю твой код, ознакомлюсь с твоими выводами и оставлю комментарии. Где то могу предложить небольшие исправление в коде, но ненавязчиво. Где потребуются уточнения, я оставлю много наводящих вопросов. Они помогут тебя с поиском верного решения.
#
# Все мои комментарии размечены по цветам, для лучшего восприятия.
#
# <div class="alert alert-success">Зеленым цветом и словом «Успех» отмечены особо удачные и элегантные решения, которыми ты можешь гордиться. </div>
#
# <div class="alert alert-warning">Желтым и значком словом «Совет», помечены решения у которых есть альтернативные решения, более оптимальные. Ты можешь найти их сразу и доработать проект, или отложить это на потом, для будущих проектах. Проект будет принят и без их доработки. </div>
#
# <div class="alert alert-danger"> Красным цветом и значком словом «Ошибка» помечу твои решения, на которые стоит обратить внимание прежде всего. После их доработки проект будет принят. </div>
#
# Залог успеха - работа сообща, взаимное уважение и работа в диалоге. Поэтому, помечай свои ответные комментарии на мои реплики заметным цветом или курсивом, так мне будет легче их отслеживать. Пожалуйста, не изменяй и не удаляй мои комментарии. Все это поможет выполнить повторную проверку быстрей.
#
# </div>

# %% [markdown]
# # Проект: "Поддержание клиентской активности в интернет-магазине 'В один клик' через персонализированные предложения"

# %% [markdown]
# <div class="alert alert-info">
# Ревьюер, приветствую! Прошу проверять работу максимально к заданию, если потребуется, что-то исправить и добавить. Так у меня горят все срок жесткого дедлайна. Надеюсь, на понимание. Заранее спасибо :)
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# Постараюсь сильно не придираться, и проверить как можно быстрее

# %% [markdown]
# <div class="alert alert-info">
# Марат, еще раз привет! Приступаю к доработкам, желтым буду пропускать из-за времени. Советы обязательно себе в блокнот, за них спасибо.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# Привет Дмитрий!  Принято

# %% [markdown]
# Проект направлен на увеличение покупательской активности постоянных клиентов интернет-магазина "В один клик". Мы предлагаем решение, основанное на анализе данных по коммуникации с клиентами, их продуктовому и покупательскому поведению, а также действиям на сайте. Используя эти данные, мы разработаем модель для прогнозирования вероятности снижения активности клиента в ближайшие три месяца. Дополнительно включены данные о прибыльности клиентов, чтобы выделить сегменты покупателей и создать для них индивидуализированные предложения. Наш подход позволит магазину эффективно удерживать постоянных клиентов и повысить их лояльность.

# %% [markdown]
# В ходе проекта мы будем следовать следующему плану:
#
# 1.	Сбор данных: Начнем с сбора данных по клиентам, включая информацию о их коммуникации с сотрудниками компании, продуктовом и покупательском поведении, а также действиях на сайте. Также интегрируем данные финансового департамента о прибыльности клиентов за последние три месяца.
# 2.	Подготовка данных: Проведем предварительную обработку данных, включая очистку от выбросов, заполнение пропущенных значений и кодирование категориальных признаков.
# 3.	Анализ данных: Изучим данные, проведем исследовательский анализ данных (EDA), чтобы выявить основные закономерности, корреляции и важные особенности поведения клиентов.
# 4.	Построение модели: Разработаем модель для прогнозирования вероятности снижения покупательской активности клиента в следующие три месяца.
# 5.	Оценка модели: Оценим качество модели с помощью различных метрик, таких как ROC-AUC.
# 6.	Интеграция данных о прибыльности клиентов: Используем данные о прибыльности клиентов для выделения сегментов покупателей и определения их ценности для компании.
# 7.	Разработка персонализированных предложений: На основе результатов моделирования и данных о прибыльности клиентов разработаем индивидуализированные предложения для каждого сегмента покупателей.
# 8.	Тестирование и оптимизация: Протестируем персонализированные предложения на выборке клиентов и оценим их эффективность.
# 9.	Отчетность и анализ результатов: Регулярно составляем отчеты о результативности стратегии, анализируем ее влияние на покупательское поведение и прибыльность магазина. На основе этих данных принимаем решения о дальнейших шагах и корректировках стратегии.

# %% [markdown]
# ## Подготовка и сбор данных

# %%
#импорт библиотек и настройка отображения 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import shap

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import (
    StandardScaler,
    MinMaxScaler,
    RobustScaler, 
    OneHotEncoder, 
    OrdinalEncoder)
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import roc_auc_score

sns.set(rc={'figure.figsize':(20, 10)})

RANDOM_STATE = 42
TEST_SIZE = 0.25

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
# Собираем все импорты в верхней части, чтобы легче было ориентироваться и добавлять новые по необходимости.
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
#
#
#
# - есть рекомендации PEP-8 при написании кода, в том числе и для импортов. Если интересно можешь почитать [тут](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html). В будущем может пригодится
#
#
#
# -  константы в отдельную ячейку пишем

# %%
# загружаем датасеты
# в некоторых файлах разделитель значений — точка с запятой, а разделитель десятичных значений — запятая
market = pd.read_csv('/datasets/market_file.csv')
m_money = pd.read_csv('/datasets/market_money.csv')
m_time = pd.read_csv('/datasets/market_time.csv')
money = pd.read_csv('/datasets/money.csv', sep=';', decimal=",")

# %%
# функция для стандартизации и очистки данных в DataFrame
def clean_dataframe(df):
    # приведем имена колонок к нижнему регистру, заменим пробелы на подчеркивания
    df.columns = df.columns.str.lower().str.replace(' ', '_')
    
    # приведем значения в колонках к нижнему регистру
    df = df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
    
    return df

# функция для вывода информации о DataFrame с помощью метода info() и отображения табличных значений с помощью display()
def display_info(df_list):
    for df in df_list:
        print("Info о DataFrame:")
        display(df.info())
        print("Табличные значения DataFrame:")
        display(df)

market = clean_dataframe(market)
m_money = clean_dataframe(m_money)
m_time = clean_dataframe(m_time)
money = clean_dataframe(money)

display_info([market, m_money, m_time, money])
# Out:
# Info о DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   1300 non-null   int64
#  1   покупательская_активность            1300 non-null   object
#  2   тип_сервиса                          1300 non-null   object
#  3   разрешить_сообщать                   1300 non-null   object
#  4   маркет_актив_6_мес                   1300 non-null   float64
#  5   маркет_актив_тек_мес                 1300 non-null   int64
#  6   длительность                         1300 non-null   int64
#  7   акционные_покупки                    1300 non-null   float64
#  8   популярная_категория                 1300 non-null   object
#  9   средний_просмотр_категорий_за_визит  1300 non-null   int64
#  10  неоплаченные_продукты_штук_квартал   1300 non-null   int64
# ...

# %% [markdown]
# Все датасеты на вид ккорректные, правильные типы данных, отсутствие пропусков.

# %%
def check_duplicates(df_list):
    duplicates_info = {}
    for idx, df in enumerate(df_list):
        duplicates = df.duplicated().any()
        if duplicates:
            duplicates_info[f'DF_{idx+1}'] = "Дубликаты присутствуют"
        else:
            duplicates_info[f'DF_{idx+1}'] = "Дубликаты отсутствуют"
    return duplicates_info

# Проверка дубликатов в каждом из загруженных DataFrame
duplicates_info = check_duplicates([market, m_money, m_time, money])

# Вывод информации о наличии дубликатов
for df_name, info in duplicates_info.items():
    print(f"{df_name}: {info}")
# Out:
# DF_1: Дубликаты отсутствуют
# DF_2: Дубликаты отсутствуют
# DF_3: Дубликаты отсутствуют
# DF_4: Дубликаты отсутствуют

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍 нужные операции выделены в  функции
#
#
#
#
#
#
# <div class="alert alert-warning">
#
#
#  Совет:
#
#
# И парочку cоветов по оформлению функций:
#
# - Для таких простых функций острой необходимости нет, код говорит сам за себя, но если хочешь попрактиковаться, можешь включить строку документации [docstring](https://dzen.ru/a/Yw02qy-7BGdhFhN3?utm_referer=yandex.ru).  Можно оставить описание того что делает эта функция, а затем попробовать вызвать что та напишешь с помощью
#
#
#     print(my_function.__doc__)
#
# или
#
#     help(my_function)

# %%
# переименую столбцы для удобства

market.rename(columns={'разрешить_сообщать': 'рассылка'}, inplace=True)
market.rename(columns={'маркет_актив_6_мес': 'маркет_ср'}, inplace=True)
market.rename(columns={'маркет_актив_тек_мес': 'маркет_тек'}, inplace=True)
market.rename(columns={'средний_просмотр_категорий_за_визит': 'средний_просмотр'}, inplace=True)
market.rename(columns={'неоплаченные_продукты_штук_квартал': 'неоплач_продукты'}, inplace=True)
market.rename(columns={'страниц_за_визит': 'просмотр_страниц'}, inplace=True)
market.rename(columns={'акционные_покупки': 'акц_покупки'}, inplace=True)
market.rename(columns={'страниц_за_визит': 'просмотр_страниц'}, inplace=True)

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍 В соответствии с требованиями к стилистике

# %%
# Получение информации о количестве уникальных значений для каждого категориального столбца
categorical_columns = ['покупательская_активность', 'тип_сервиса', 'рассылка', 'популярная_категория']
for column in categorical_columns:
    unique_values = market[column].value_counts()
    print(f"Уникальные значения для столбца '{column}':")
    print(unique_values)
    print()
# Out:
# Уникальные значения для столбца 'покупательская_активность':
# прежний уровень    802
# снизилась          498
# Name: покупательская_активность, dtype: int64
#
# Уникальные значения для столбца 'тип_сервиса':
# стандарт     914
# премиум      376
# стандартт     10
# Name: тип_сервиса, dtype: int64
#
# Уникальные значения для столбца 'рассылка':
# да     962
# нет    338
# Name: рассылка, dtype: int64
#
# Уникальные значения для столбца 'популярная_категория':
# товары для детей                        330
# домашний текстиль                       251
# косметика и аксесуары                   223
# техника для красоты и здоровья          184
# мелкая бытовая техника и электроника    174
# кухонная посуда                         138
# Name: популярная_категория, dtype: int64

# %%
# Получение информации о количестве уникальных значений для каждого категориального столбца
categorical_columns = ['период']
for column in categorical_columns:
    unique_values = m_money[column].value_counts()
    print(f"Уникальные значения для столбца '{column}':")
    print(unique_values)
    print()
# Out:
# Уникальные значения для столбца 'период':
# текущий_месяц          1300
# предыдущий_месяц       1300
# препредыдущий_месяц    1300
# Name: период, dtype: int64

# %%
# Получение информации о количестве уникальных значений для каждого категориального столбца
categorical_columns = ['период']
for column in categorical_columns:
    unique_values = m_time[column].value_counts()
    print(f"Уникальные значения для столбца '{column}':")
    print(unique_values)
    print()
# Out:
# Уникальные значения для столбца 'период':
# текущий_месяц       1300
# предыдцщий_месяц    1300
# Name: период, dtype: int64

# %% [markdown]
# После проверки явные дубликаты в данных отсутствуют. Увидел только ошибки, которые исправлю в ручную.

# %%
market['тип_сервиса'] = market['тип_сервиса'].replace('тт', 'т', regex=True)
market['тип_сервиса'].value_counts()
# Out:
# стандарт    924
# премиум     376
# Name: тип_сервиса, dtype: int64

# %%
m_time['период'] = m_time['период'].replace('дц', 'ду', regex=True)
m_time['период'].value_counts()
# Out:
# текущий_месяц       1300
# предыдущий_месяц    1300
# Name: период, dtype: int64

# %% [markdown]
#
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех:
#
#
#
# - Здорово что обращено внимание на   скрытые дубликаты
#
#
#
#
#
#
# <div class="alert alert-warning">
#
# Совет:
#
#
#
#
# - можно еще поискать грамматические ошибки, их тут хватает (кстати повлияют ли грамматические ошибки на работу модели?)
#
#
# - можешь предложить как можно искать такие описки и скрытые дубликаты автоматически?
#
#
# ажение которое найдет слова с повторяющимися буквами внутри слова

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# 1. Проанализируем данные в каждой таблице, изучив общую информацию, описательную статистику и распределения значений.
# 2. Определим клиентов, которые совершали покупки в каждом из трех месяцев.
# 3. Отфильтруем данные, оставив только клиентов с покупательской активностью не менее трех месяцев.
# 4. Оценим количество клиентов, удовлетворяющих этому условию, и представим основные результаты и выводы.

# %%
market.describe().T
# Out:
#                    count           mean         std       min        25%  \
# id                1300.0  215997.500000  375.421985  215348.0  215672.75
# маркет_ср         1300.0       4.253769    1.014814       0.9       3.70
# маркет_тек        1300.0       4.011538    0.696868       3.0       4.00
# длительность      1300.0     601.898462  249.856289     110.0     405.50
# акц_покупки       1300.0       0.319808    0.249843       0.0       0.17
# средний_просмотр  1300.0       3.270000    1.355350       1.0       2.00
# неоплач_продукты  1300.0       2.840000    1.971451       0.0       1.00
# ошибка_сервиса    1300.0       4.185385    1.955298       0.0       3.00
# просмотр_страниц  1300.0       8.176923    3.978126       1.0       5.00
#
#                         50%        75%        max
# id                215997.50  216322.25  216647.00
# маркет_ср              4.20       4.90       6.60
# маркет_тек             4.00       4.00       5.00
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
#
#
# Можно повернуть таблицу, применив метод df.T, так возможно будет проще анализировать

# %% [markdown]
# <div class="alert alert-info">
# Спасибо.
# </div>

# %%
# Функция для построения гистограммы распределения значений
def plot_distribution(data, column, bins=None):
    plt.figure(figsize=(8, 6))
    plt.hist(data[column], bins=bins, edgecolor='k', alpha=0.7)
    plt.title(f"Распределение значений для переменной '{column}'", fontsize=15)
    plt.xlabel(column, fontsize=12)
    plt.ylabel('Частота', fontsize=12)
    plt.grid(True)
    plt.show()

# Построение графиков для каждой переменной, кроме 'id'
for column in market.columns:
    if column != 'id' and market[column].dtype in ['int64', 'float64']:
        plot_distribution(market, column)
    elif column != 'id':
        print(f"Переменная '{column}' не является числовой и не может быть визуализирована.")
# Out:
# Переменная 'покупательская_активность' не является числовой и не может быть визуализирована.
# Переменная 'тип_сервиса' не является числовой и не может быть визуализирована.
# Переменная 'рассылка' не является числовой и не может быть визуализирована.
# Переменная 'популярная_категория' не является числовой и не может быть визуализирована.

# %%
market['тип_сервиса'].value_counts().sort_values().plot.barh(figsize=(20, 5))
plt.title('Распределение типа сервиса')
plt.xlabel('Количество пользователей')
plt.ylabel('Тип сервиса');

# %% [markdown]
# Покупателей с типом сервиса стандарт больше, чем премиум почти в два раза.

# %%
market['рассылка']\
.value_counts().sort_values().plot.barh(figsize=(20, 5))
plt.title('Распределение одобрения рассылок')
plt.xlabel('Количество пользователей')
plt.ylabel('Рассылка');

# %% [markdown]
# Большая часть покупателей положительно смотрит на последующую рекламную рассылку.

# %%
market['популярная_категория']\
.value_counts().sort_values().plot.barh(figsize=(20, 5))
plt.title('Распределение популярных категорий')
plt.xlabel('Количество пользователей')
plt.ylabel('Популярные категории');

# %% [markdown]
# Самый большой спрос категории семейных покупок: товары для детей, домашний текстиль.

# %% [markdown]
# В общем и целом я бы сказал, что все данные ведут себя разумно.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Совет 🤔:
#
#
#
# - Не забываем поднимать импорты наверх.  А функции мы оставляем сразу после импортов.  Так легче контролировать
#
#
#
# - Не очень понятно что такое разумно.  Тут мы смотрим насколько нормально распределены признаки, это нам поможет правильно посчитать корреляцию

# %%
m_money.describe()
# Out:
#                   id        выручка
# count    3900.000000    3900.000000
# mean   215997.500000    5025.696051
# std       375.325686    1777.704104
# min    215348.000000       0.000000
# 25%    215672.750000    4590.150000
# 50%    215997.500000    4957.500000
# 75%    216322.250000    5363.000000
# max    216647.000000  106862.200000

# %%
# Построение боксплота
plt.figure(figsize=(8, 6))
plt.boxplot(m_money['выручка'])
plt.title('Боксплот для переменной "выручка"', fontsize=15)
plt.ylabel('выручка', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Наблюдаются, конечно, выбросы, но в целом только напрягают покупатели, выручка от которых выше 100000 рублей и 0 рублей.

# %%
display(m_money[m_money['выручка'] > 100000])
display(m_money[m_money['выручка'] == 0])
# Out:
#         id         период   выручка
# 98  215380  текущий_месяц  106862.2
#         id               период  выручка
# 0   215348  препредыдущий_месяц      0.0
# 2   215348     предыдущий_месяц      0.0
# 28  215357  препредыдущий_месяц      0.0
# 29  215357     предыдущий_месяц      0.0
# 34  215359     предыдущий_месяц      0.0
# 35  215359  препредыдущий_месяц      0.0

# %%
#удалим этот выброс
m_money = m_money.drop([0, 2, 28, 29, 34, 35, 98])

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# Хотя убрать лучше не через индексы, малейшие изменения в датасете и всё пойдёт криво

# %%
# Построение боксплота
plt.figure(figsize=(8, 6))
plt.boxplot(m_money['выручка'])
plt.title('Боксплот для переменной "выручка"', fontsize=15)
plt.ylabel('выручка', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Ну вот 1300 активных и нормальных покупателей.

# %%
# строим график распределения выручки по периодам
fig, ax = plt.subplots(figsize=(20, 5))
plt.title('Распределение выручки по периодам')
ax.hist(m_money.query('период == "текущий_месяц"')['выручка'], 
        bins=50, alpha=0.5, label='текущий_месяц')
ax.hist(m_money.query('период == "предыдущий_месяц"')['выручка'], 
        bins=50, alpha=0.5, label='предыдущий_месяц')
ax.hist(m_money.query('период == "препредыдущий_месяц"')['выручка'], 
        bins=50, alpha=0.5, label='препредыдущий_месяц')
ax.set(xlabel='Сумма выручки', ylabel='Покупатели')
ax.legend()
plt.show()

# %%
# строим графики распределения времени помещения сайта по периодам
fig, ax = plt.subplots(figsize=(20, 5))
plt.title('Распределение времени посещения сайта')
ax.hist(m_time.query('период == "текущий_месяц"')['минут'], 
        bins=20, alpha=0.5, label='текущий_месяц')
ax.hist(m_time.query('период == "предыдущий_месяц"')['минут'], 
        bins=19, alpha=0.5, label='предыдущий_месяц')
ax.set(xlabel='Время', ylabel='Покупатели')
ax.legend()
plt.show()

# %%
money['прибыль'] *= 1000
plt.figure(figsize=(10, 5))
plt.hist(money['прибыль'], bins=20, alpha=0.5, color='b')
plt.title('Распределение прибыли')
plt.xlabel('Прибыль')
plt.ylabel('Количество пользователей')
plt.grid(True)
plt.show()

# %% [markdown]
# Прибыли распределяется примерно так же как и выручка, что впринципе логично.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Успех:
#
#
# Из плюсов:
#
#
# - Правильно что продолжаешь практику с прошлого проекта и строишь 2 типа графиков для количественных признаков
#
#
# - Написана функция для графика
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет 🤔:
#
#
# - можно пойти дальше  и для графиков распределений сделать разбивку по таргету. Так мы можем получить дополнительную информацию для лучшего понимания наших данные, может что-то пригодится для раздела сегментации. Если использовать seaborn, это можно сделать с помощью аргумента [hue](https://www.statology.org/seaborn-histogram-hue/). В результате мы получим наложенные (в разбивки по таргету) 2 гистограммы (boxplot тоже неплохо добавить) для каждого количественного признака. И о категориальных незабываем. Будет красиво и информативно.
#
#
#
# - для красоты восприятия рекомендую использовать [subplots](https://nagornyy.me/it/vizualizatsiia-dannykh-v-matplotlib/): один столбец гистограммы, другой boxplot
#
#
#
#
# - а ещё бы  посоветовал использовать библиотеку    [seaborn](https://nagornyy.me/it/vizualizatsiia-dannykh-v-seaborn/), она строит  симпатичнее и проще matplotlib. Использовать matplotlib это как выучиться на механике, но если умеешь на механике но на автомате (seaborn) точно получится. Есть небольшие отличия в названиях графиках, и фнкциональных возможностях, но это мелочи

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка ❌:
#
#
#
# Не забываем построить графики для категориальных признаков.  И для признаков из других выборок
#
#
# <div class="alert alert-warning">
#
#
#
# Совет:
#
#
# - для гистограмм по выручке и минутам, стоит предварительно сделать группировку по "период" (у нас будет 3 графика по выручке и 2 по минутам), это разумно, ведь именно в таком виде мы используем их

# %% [markdown]
# <div class="alert alert-info">
# Графики добавил, разместил все гистограммы на одном для удобства чтения.
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Ошибка ❌:
#
#
#
#
# Хорошо что ты сделал разбивку по периоду.  Но это был совет, главное было исправить ошибку - ошибка в том что у тебя нет графиков для категориальных признаков (для них используем pie...bar....count)

# %% [markdown]
# <div class="alert alert-info">
# Добавил категориальные графики датасета market и график прибыли датасета money.
# </div>

# %% [markdown]
# Анализ данных позволяет сделать следующие выводы:
#
# 1. Не выявлено явных выбросов в данных. Все значения, находящиеся за пределами 95-го процентиля, могут быть объяснимы особенностями покупательского поведения.
# 2. Большинство клиентов сохраняют прежний уровень покупательской активности. Это следует учитывать при построении моделей, так как классы могут быть несбалансированными.
# 3. Стандартный тип сервиса наиболее распространен среди покупателей.
# 4. Большинство покупателей разрешают отправлять им дополнительные предложения.
# 5. В среднем за полгода каждый покупатель получает 4 маркетинговых рассылки, причем за последний месяц большинство покупателей также получили 4 рассылки.
# 6. Самая популярная категория товаров - товары для дома.
# 7. В среднем каждый квартал покупатели не оплачивают 3 товара и просматривают 8 страниц на сайте.
# 8. В среднем на пользователя приходится 4 ошибки на сайте.
# 9. В данных о выручке присутствовало аномальное значение - 106862.20. Это значение мы посчитали выбросом и удалили, как и покупатели с нулевой выручкой.
# 10. В данных отобраны только клиенты, которые что-то покупали в течение трех месяцев. Таких клиентов - 1297.

# %% [markdown]
# ## Объединение таблиц

# %%
m_money_pivot = (m_money
                      .pivot_table(index='id', 
                                   columns='период', 
                                   values='выручка', 
                                   aggfunc='sum')
                      .rename(columns={'предыдущий_месяц': 'выручка_пред',
                                       'препредыдущий_месяц': 'выручка_препред',
                                       'текущий_месяц': 'выручка_тек'})
                      .dropna()
                      .reset_index())
m_money_pivot.head()
# Out:
# период      id  выручка_пред  выручка_препред  выручка_тек
# 0       215349        5216.0           4472.0       4971.6
# 1       215350        5457.5           4826.0       5058.4
# 2       215351        6158.0           4793.0       6610.4
# 3       215352        5807.5           4594.0       5872.5
# 4       215353        4738.5           5124.0       5388.5

# %%
m_time_pivot = (m_time
                     .pivot_table(index='id', 
                                  columns='период', 
                                  values='минут', 
                                  aggfunc='sum')
                     .fillna(0)
                     .rename(columns={'предыдущий_месяц': 'минут_пред',
                                      'текущий_месяц': 'минут_тек'})
                     .reset_index())

# %%
total_market = (market
         .merge(m_money_pivot, 
                how='inner',
                left_on='id',
                right_on='id')
         .merge(m_time_pivot, 
                how='inner',
                left_on='id',
                right_on='id'))

total_market.head()
# Out:
#        id покупательская_активность тип_сервиса рассылка  маркет_ср  \
# 0  215349                 снизилась     премиум       да        4.4
# 1  215350                 снизилась    стандарт      нет        4.9
# 2  215351                 снизилась    стандарт       да        3.2
# 3  215352                 снизилась    стандарт      нет        5.1
# 4  215353                 снизилась    стандарт       да        3.3
#
#    маркет_тек  длительность  акц_покупки популярная_категория  \
# 0           4           819         0.75     товары для детей
# 1           3           539         0.14    домашний текстиль
# 2           5           896         0.99     товары для детей
# 3           3          1064         0.94     товары для детей
# 4           4           762         0.26    домашний текстиль
#
#    средний_просмотр  неоплач_продукты  ошибка_сервиса  просмотр_страниц  \
# 0                 4                 4               2                 5
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# - данные для моделирования подготовлены
#
#
#
# - не активные клиенты убраны
#
#
# - 👍pivot_table

# %% [markdown]
# ## Корреляционный анализ

# %%
total_market['покупательская_активность'] = (total_market['покупательская_активность'] != 'снизилась' * 1)

total_market.sample(10)
# Out:
#           id  покупательская_активность тип_сервиса рассылка  маркет_ср  \
# 948   216300                       True    стандарт       да        3.7
# 1047  216399                       True    стандарт       да        3.8
# 347   215699                      False    стандарт      нет        4.1
# 1267  216619                       True    стандарт      нет        3.9
# 713   216065                       True    стандарт       да        4.1
# 642   215994                       True    стандарт       да        5.1
# 553   215905                      False    стандарт       да        4.3
# 768   216120                       True    стандарт      нет        4.3
# 281   215633                      False     премиум       да        4.4
# 670   216022                       True    стандарт       да        4.5
#
#       маркет_тек  длительность  акц_покупки  \
# 948            4           714         0.26
# 1047           4           265         0.95
# ...

# %%
#сделаем корреляционный анализ по методу Спирмана
correlation_matrix = total_market.drop('id', axis=1).corr(method='spearman')

# Создание тепловой карты с аннотациями
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, cmap="coolwarm", annot=True)
plt.show()

# %% [markdown]
#
#
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
#
#
#
#
# - при работе с не нормально распределенными признаками был подсчитан Спирмен, а не Пирсон
#
#
#
#
#
#
#
# <div class="alert alert-warning">
#
#
# Совет:
#
#
# - можно поменять политру для удобства восприятия, через добавление cmap='coolwarm' ('bwr', 'seismic'), тогда чем ближе корреляция к 1 тем красней, чем ближе к -1 тем "синей" , ну и чем меньше связи, чем ближе к 0, тем нейтальней цвет
#
#
#
#
#
#
#
#
# - можно построить дополнительно  матрицы корреляций для двух датасетов разбитых по таргету. Затем проанализировать есть ли отличия в корреляции, это может быть полезно для лучшего понимания нашей данных

# %% [markdown]
# Из анализа матрицы корреляции:
#
# Маркетинговая активность (маркет_ср и маркет_тек) имеет слабую положительную корреляцию между собой (коэффициент корреляции ≈ 0.06).
#
# Длительность посещения магазина не коррелирует с маркетинговой активностью и оказывает незначительное воздействие на другие переменные (коэффициент корреляции ≈ -0.04).
#
# Акционные покупки имеют слабую отрицательную корреляцию с маркетинговой активностью (коэффициент корреляции ≈ -0.28). Это может указывать на то, что клиенты, совершающие акционные покупки, менее реагируют на маркетинговые действия.
#
# Средний просмотр категорий также слабо коррелирует с маркетинговой активностью (коэффициент корреляции ≈ 0.19).
#
# Количество неоплаченных продуктов имеет слабую отрицательную корреляцию с акционными покупками (коэффициент корреляции ≈ 0.20), что может означать, что клиенты, совершающие акционные покупки, реже оставляют товары неоплаченными.
#
# Ошибки сервиса показывают незначительную корреляцию с остальными переменными.
#
# Просмотр страниц на сайте имеет слабую положительную корреляцию с маркетинговой активностью и средним просмотром категорий (коэффициент корреляции ≈ 0.32 и ≈ 0.27 соответственно).
#
# Минуты, проведенные на сайте, имеют слабую положительную корреляцию друг с другом и со средним просмотром страниц (коэффициенты корреляции ≈ 0.36 - 0.45).
#
# Выручка (в предыдущем, предпредыдущем и текущем месяцах) сильно коррелирует между собой (коэффициенты корреляции ≈ 0.88), что логично, учитывая, что это показатель дохода от продаж.

# %% [markdown]
# Существует высокая корреляция между некоторыми переменными, например, между выручкой в различные периоды времени (в предыдущем, предпредыдущем и текущем месяцах), а также между количеством минут, проведенных на сайте.

# %% [markdown]
#
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка ❌:
#
#
#
# Обычно мультиколлинеарность если корреляция больше 0,9
#
#
# <div class="alert alert-warning">
#
# Совет:
#
#
#
#
# - можешь провести дополнительное исследование с помощью    VIF (Variance Inflation Factor)
#
#
#
# - а для каких можелей проблема мультиколинеарность?  Может не так всё и проблемно?

# %% [markdown]
# <div class="alert alert-info">
# Сделал исследование с помощью VIF.
# </div>

# %%
total_market_numeric = total_market.select_dtypes(include=['float64', 'int64'])  # Оставляем только числовые признаки
total_market_numeric = total_market_numeric.dropna()  # Удаляем строки с пропущенными значениями

# рассчитываем VIF
X = add_constant(total_market_numeric.drop(columns=['выручка_пред']))  # Добавляем константу для расчета VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

vif_data
# Out:
#              feature            VIF
# 0              const  588836.567099
# 1                 id       1.784238
# 2          маркет_ср       1.237955
# 3         маркет_тек       1.044451
# 4       длительность       1.102360
# 5        акц_покупки       1.197282
# 6   средний_просмотр       1.185474
# 7   неоплач_продукты       1.216421
# 8     ошибка_сервиса       1.079319
# 9   просмотр_страниц       1.499038
# 10   выручка_препред       1.338890
# 11       выручка_тек       1.098747
# 12        минут_пред       1.593917
# 13         минут_тек       1.380087

# %% [markdown]
# Обычно значения VIF выше 10 указывают на проблему мультиколлинеарности, действительно у нас такой проблемы нет.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет 🤔:
#
#
#
#
#
#
# В прошлом проекте мы активно использовали scatter_plot для уточнения характера связи между признаками и удоем, и на основе увиденного сделали некоторые преобразования, помогающие преодолеть ограничения линейной модели. В этом проекте мы используем нелинейные модели для которых это не проблема, и таргет у нас не количественный а категориальный. Тем не менее и в этом проекте можно построить scatter_plot между количественными признаками, а таргет использовать  в качестве фильтра. Напомню что проще всего это реализовать с помощью [sns.PairGrid](https://seaborn.pydata.org/generated/seaborn.PairGrid.html). Это не пригодится нам для улучшения метрики, но возможно мы увидим что то полезное для сегментации или лучшего понимания наших данных.
#
# - Можно c помощью scatter_plot сконцентрироваться на связи между выручка текущая - выручка за прошлый. Там явная линейная зависимость, причем как будто бы множество точек тяготеют к двум прямым. Можно поискать факторы которые описывает эти два разных множества. Можно к выручке за прошлый месяц добавить выручку за позапрошлый месяц (или отнять) и тогда в каких то группировках по категориальным признакам будет очень четкая линейная зависимость достигающая по r2 за 0.9. Из этого можно сделать вывод что  в определенных группировках, зависимость между выручками за разные периоды практически дерерминирована (очень высокий показатель r2), то есть из выручки за прошлый (и с учетом позапрошлого месяца) мы можем точно спрогнозировать расходы клиента за текущий месяц. О чем это может говорить?
#
#
#
# - Можно посмотреть scatter_plot между id и акционными покупками. Можно кое что интересное увидеть и дать этому обьяснение

# %% [markdown]
# ## Использование пайплайнов

# %% [markdown]
# Наша задача построить пайплайн.

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
# Совет:
#
# Лучше вручную закодировать "снизилась" единицей, "осталось" - нулем, или хотя бы убедиться что все получилось как надо
#
# Когда у нас бинарная классификация, то метрики presicion, recall, f1 считаются (и подбирается в GS) толко по положительному классу.  Положительный класс - это тот класс который нас больше интересует, по постановке задачи видно что это "снизили активность". А так непонятно как у тебя закодировалось

# %%
# создадим матрицы признаков и целевой переменной 'покупательская активность'
X = total_market.drop(['id', 'покупательская_активность'], axis=1)
y = total_market['покупательская_активность']

# разделим данные на обучающий и тестовый наборы
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify=y,
                                                    test_size=TEST_SIZE,
                                                    random_state=RANDOM_STATE) # значения задавали в самом начале
# определим категориальные и числовые признаки
cat_columns = X_train.select_dtypes('object').columns
num_columns = X_train.select_dtypes('float').columns

# создадим пайплайн для обработки категориальных признаков
cat_pipe = Pipeline(
    [
        (
            'simpleImputer_before_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        ),
        (
            'encoder', 
            OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=np.nan)),
        (
            'simpleImputer_after_ord', 
            SimpleImputer(missing_values=np.nan, strategy='most_frequent')
        )
    ]
)

# создадим общий пайплайн для преобработки данных
data_pipe = ColumnTransformer(
    [
        (
            'cat', 
            cat_pipe,
            cat_columns
        ),
        (
            'num', 
            StandardScaler(), 
            num_columns
        ),
    ]
)

#  создадим пайплайн с моделью решающего дерева
final_pipe = Pipeline(
    [
        ('preprocessor', data_pipe),
        ('classifier', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)
# обучаем модель
final_pipe.fit(X_train, y_train)

# получаем прогнозы на тестовом наборе и оценка метрики качества модели
y_test_pred = final_pipe.predict_proba(X_test)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred[:, 1])}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.709516129032258

# %% [markdown]
# ROC-AUC в значении 0.71 означает, что модель демонстрирует неплохую способность различать между классами "потенциальные покупатели" и "непокупатели", однако, значение 0.70 означает, что есть некоторое пространство для улучшения. Модель может быть доработана для улучшения ее точности и способности различения классов.
#
# Этот результат может быть полезным для оптимизации маркетинговых кампаний и снижения затрат на рекламу и привлечение клиентов, но при этом также может быть целесообразно провести дополнительные исследования для улучшения модели и повышения ее эффективности, что мы и сделаем.

# %% [markdown]
#
#
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка ❌:
#
# - OrdinalEncoder можно попробовать использовать, когда значения категориального признака имеют внутренний порядок (низкий/средний/высокий, майор/полковник/генерал), иначе модель будет пытаться найти какие то порядковые отношения, которых нет.
#
#
# - Пока не выберем лучшую модель на кросс валидации тестовой выборке для нас как будто не существует
#
#
#
# - Стоит обосновать метрику   roc_auc. Хорошо бы ее увязать с нашими бизнес-задачами
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
#
# - Я бы видел список твоих категориальных и количественных признаков, не надо превращать свою предобработку в чёрный ящик
#
#
# В будущем при предобработке данных можешь учитывать следующие моменты:
#
#
# - если у категориального признака большое количество уникальных значений, применение One-Hot Encoding может привести к большому количеству новых признаков, это усложнит работу моделей
#
# - у catboost и lighgbm есть собственные инструменты работы с категориальными данными, нужно только указать какие столбца содержат категориальные данные
#
# - при работе с количественными признаками для линейных и метрических (модели в которых измеряется расстояние) моделей  обязательно делаем Scaler, в отличие от моделей на основе деревьев решений, для них Scaler не нужен
#
#
# Можешь подумать над вопросом почему для линейных моделей некорректное использование OrdinalEncoder может вызвать больше проблем чем для случайного леса  или других моделей в основе которых лежат деревья решений

# %% [markdown]
# <div class="alert alert-info">
# Ну я же далее использовал GridsearchCV, этот инстурмент автоматически выполняет кросс-валидацию для каждой комбинации параметров. Дал вывод по ROC-AUC для наших бизнес-задач.
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
#
#
# То есть ты как бы сначала решил проверить одну модель - Дерево решений.  Проверил её на тестой - увидел что метрика нехорошая и решидл сделать перебор?!
#
#
# Тогда   нарушения логики моделирования нет, оке. Хотя я всё равно убрал бы
#
#
#
#     # обучаем модель
#     final_pipe.fit(X_train, y_train)
#
#     # получаем прогнозы на тестовом наборе и оценка метрики качества модели
#     y_test_pred = final_pipe.predict_proba(X_test)
#     print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred[:, 1])}')
#
#
#
# Всё-таки это проект, а не черновик
#
#
#
#
# А во-вторых ты никак не обосновал метрику roc-auc ( Тут стоило написать чем Она хороша в отличие от других метрик, или увязать её с бизнес-задачей)

# %%
# определим параметры для настройки моделей
# для LogisticRegression
param_grid = {
    'preprocessor__cat__encoder': [OneHotEncoder(drop='first')],
    'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'classifier__C': range(1, 5),
    'classifier__penalty': ['l2', 'l1'],
    'classifier': [LogisticRegression(random_state=RANDOM_STATE, solver='liblinear', max_iter=1000)]
}


# для KNeighborsClassifier
param_knn = {
    'preprocessor__cat': [OneHotEncoder(drop='first')],
    'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'classifier__n_neighbors': [2, 5, 10, 25, 50],
    'classifier': [KNeighborsClassifier()]
}

# для DecisionTreeClassifier
param_dtc = {
    'preprocessor__cat__encoder': [OrdinalEncoder(), OneHotEncoder(drop='first')],
    'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'classifier__max_depth': range(2, 11),
    'classifier__min_samples_leaf': range(2, 10),
    'classifier__min_samples_split': range(2, 10),
    'classifier': [DecisionTreeClassifier(random_state=RANDOM_STATE)]
}

# Параметры для SVC
param_svc = {
    'preprocessor__cat__encoder': [OrdinalEncoder(), OneHotEncoder(drop='first')],
    'preprocessor__num': [StandardScaler(), MinMaxScaler(), RobustScaler()],
    'classifier__C': [10**-2, 10**-1, 10**0, 10**1, 10**2],
    'classifier': [SVC(probability=True, random_state=RANDOM_STATE)]
}

# %%
# подбираем оптимальных параметров моделей с использованием GridSearchCV
params = [param_grid, param_knn, param_dtc, param_svc]
grid = GridSearchCV(final_pipe, 
                    params, 
                    cv=5, 
                    n_jobs=-1,
                    scoring='roc_auc')
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('cat',
#                                                                          Pipeline(steps=[('simpleImputer_before_ord',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('encoder',
#                                                                                           OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                                          unknown_value=nan)),
#                                                                                          ('simpleImputer_after_ord',
# ...

# %%
# вывод результатов
print('Лучшая модель и её параметры:\n\n', grid.best_estimator_)
print('Метрика ROC-AUC для лучшей модели:\n', grid.best_score_)
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('simpleImputer_before_ord',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OrdinalEncoder()),
#                                                                   ('simpleImputer_after_ord',
#                                                                    SimpleImputer(strategy='most_frequent'))]),
#                                                   Index(['тип_сервиса', 'рассылка', 'популярная_категория'], dtype='object')),
#                                                  ('num', StandardScaler(),
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# - pipelines + ColumnTransformer + автоподбор построены
# - 'passthrough' не забыт
# - drop='first’ указан
# - 2 способа масштабирование
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
#
#
#
# - бывает полезно замерить время исполнения кода в ячейке, это можно сделать с помощью магической функции %%time
#
#
#
# - в нашем проекте мы использовали pipeline со стандартными функциями sklearn (StandardScaler, MinMaxScaler итд итп), но ведь у нас может быть своя собственная функция преобразования данных. Например мы хотим заполняем пропуски средней в какой то группировке, но должны учесть логику моделирования, по которой мы можем использовать только данные из train (делаем .fit), а затем "обученную на train функцию преобразования" используем на test/valid (делаем .transform), по ссылкам можно посмотреть как это можно реализовать [Ссылка 1](https://dzen.ru/media/id/5ee6f73b7cadb75a66e4c7e3/sozdanie-polzovatelskih-preobrazovatelei-dannyh-62b2a9a80e49941961ffc7a2),
# [Ссылка 2](https://towardsdatascience.com/pipelines-custom-transformers-in-scikit-learn-the-step-by-step-guide-with-python-code-4a7d9b068156)
#
# Обрати внимание что мы создаем для этого класс, наследуя классы TransformerMixin и BaseEstimator, чтобы можно было применять  .fit(X_train), .predict(X_test)
#
#
#
# - для расширения кругозора: GridSearch/RandomizedSearch это классика, но есть и другие варианты подбора гиперпараметров, можешь [ознакомиться](https://www.freecodecamp.org/news/hyperparameter-optimization-techniques-machine-learning/). Выделю оptuna, очень много плюсов, причем изучение можно начать с [**OptunaSearchCV**](https://optuna.readthedocs.io/en/stable/reference/generated/optuna.integration.OptunaSearchCV.html). Интерфейс практически такой же, как у GridSearch/RandomizedSearch

# %%
# предсказание вероятностей классов на тестовой выборке с помощью лучшей модели
y_pred = grid.best_estimator_.predict_proba(X_test)
# вычисление метрики ROC-AUC на тестовой выборке
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_pred[:, 1])}')
# Out:
# Метрика ROC-AUC на тестовой выборке: 0.863991935483871

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# 👍
#
#
#
#
# </div>

# %% [markdown]
# ## Анализ важности признаков

# %%
# сохраняем наш лучший пайплайн
best_pipe = grid.best_estimator_
# доступ к линейной модели
linear_model = best_pipe.named_steps['classifier']

# подготовливаем данные
X_train_prep = best_pipe.named_steps['preprocessor'].fit_transform(X_train)
X_test_prep = best_pipe.named_steps['preprocessor'].transform(X_test)

explainer = shap.Explainer(linear_model.predict_proba, X_train_prep)
# вычисляем SHAP значения
shap_values = explainer(X_test_prep)
# Out:
# ExactExplainer explainer: 325it [02:48,  1.86it/s]

# %%
# строим график SHAP значений
shap.summary_plot(shap_values[:, :, 1], X_test_prep, plot_type="bar",
                  feature_names= (cat_columns.tolist() + num_columns.tolist()))

# %% [markdown]
# Наибольшую активность пользователя зависит от того, насколько интенсивно он совершал покупки в предыдущие и препредыдущие периоды. Акционные покупки оказывают сильное влияние на активность пользователя, даже несущественная вещь может стать объектом желания, особенно если ее цена значительно снижена. Так же можно отметить влияние взаимодействия с покупателем, если он разрешил такие контакты.

# %% [markdown]
#
#
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# - Построен график важности факторов, график аккуратный
#
#
# - Присутствуют выводы о том, какие факторы сильнее/слабее влияют
#
#
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет 🤔:
#
#
#
# - не стоит писать как будто есть причино - следственные связи между какими то признаками и таргетом, которые мы выявили с помощью shap. Тут стоит писать: "с точки зрения модели наиболее важными признаком для прогноза активности...".  Между признаками и таргетами существуют какие то корреляционные или вероятностные связи, которые модель выявила, не больше.
#
#
#
# - рекомендую использовать  и .beeswarm, чтобы можно посмотреть какая именно связь между факторами и таргетом. это и для сегментирования даст дополнительную информацию
# (.plots.beeswarm не принимает feature_names, но можно список имен подать когда иннициализируем explainer)
#
#
#
# - можно и по-другому оценить важность признаков, это можно сделать с помощью [.feature_importance](https://inria.github.io/scikit-learn-mooc/python_scripts/dev_features_importance.html) (но не забываем что в логистической регрессии надо учесть логарифм в функция ошибки). Или с помощью [Permutation Importance](https://scikit-learn.org/stable/modules/permutation_importance.html)

# %% [markdown]
# ## Сегментация покупателей

# %% [markdown]
# Можно считать наиболее заинтересованными пользователями тех, у кого более половины покупок были акционными, кто принес выручку выше медианного значения, а также с кем было достаточно частое взаимодействие в течение полугода.

# %%
# выполняем сегментацию покупателей
consumers = X[(X['акц_покупки'] > 0.5)
               &
               (X['выручка_препред'] > X['выручка_препред'].median())
               &
               (X['маркет_ср'] > X['маркет_тек'].median())]

# %%
consumers['популярная_категория']\
.value_counts().sort_values().plot.barh(figsize=(15, 10))
plt.title('Распределение популярных категорий')
plt.xlabel('Количество пользователей')
plt.ylabel('Популярные категории');

# %% [markdown]
# Наиболее популярные категории у пользователей являются 'мелкая бытовая техника и электрониика', почти с таким же успехом пользуется 'техника для красоты и здоровья'. Меньше всего покупают детски товары и кухонную утварь.

# %%
# строим график распределения типа сервиса
consumers['рассылка']\
.value_counts().sort_values().plot.barh(figsize=(20, 5))
plt.title('Распределение наличия рассылки')
plt.xlabel('Количество пользователей')
plt.ylabel('рассылка');

# %% [markdown]
# Большинство сегментируемых пользователей пользователей пользуются рассылкой.

# %%
# строим график распределения типа сервиса
consumers['тип_сервиса']\
.value_counts().sort_values().plot.barh(figsize=(20, 5))
plt.title('Распределение типа сервиса')
plt.xlabel('Количество пользователей')
plt.ylabel('Тип сервиса');

# %% [markdown]
# <div class="alert alert-danger">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Ошибка ❌:
#
#
#
#
#
# А может стоило провести сравнение с покупателями которые не вошли в твой сегмент? Этого можно было построить на одной графики распределения признаков для твоего сегмента и для них

# %% [markdown]
# <div class="alert alert-info">
# Проанализировал, сделал выводы.
# </div>

# %% [markdown]
# Стандартных пользователей почти в два раза больше премиум аккаунтов.

# %%
# выберем покупателей, не вошедших в сегмент
non_segment_consumers = X[~X.index.isin(consumers.index)]

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(15, 10))

consumers['популярная_категория'].value_counts().plot.barh(ax=axes[0, 0], color='blue', alpha=0.7, label='Сегмент')
non_segment_consumers['популярная_категория'].value_counts().plot.barh(ax=axes[0, 0], color='orange', alpha=0.7, label='Не в сегменте')
axes[0, 0].set_title('Распределение популярных категорий')
axes[0, 0].set_xlabel('Количество пользователей')
axes[0, 0].set_ylabel('Популярные категории')
axes[0, 0].legend()

consumers['рассылка'].value_counts().plot.barh(ax=axes[0, 1], color='blue', alpha=0.7, label='Сегмент')
non_segment_consumers['рассылка'].value_counts().plot.barh(ax=axes[0, 1], color='orange', alpha=0.7, label='Не в сегменте')
axes[0, 1].set_title('Распределение наличия рассылки')
axes[0, 1].set_xlabel('Количество пользователей')
axes[0, 1].set_ylabel('Рассылка')
axes[0, 1].legend()

consumers['тип_сервиса'].value_counts().plot.barh(ax=axes[1, 0], color='blue', alpha=0.7, label='Сегмент')
non_segment_consumers['тип_сервиса'].value_counts().plot.barh(ax=axes[1, 0], color='orange', alpha=0.7, label='Не в сегменте')
axes[1, 0].set_title('Распределение типа сервиса')
axes[1, 0].set_xlabel('Количество пользователей')
axes[1, 0].set_ylabel('Тип сервиса')
axes[1, 0].legend()

sns.kdeplot(consumers['выручка_препред'], ax=axes[1, 1], color='blue', label='Сегмент')
sns.kdeplot(non_segment_consumers['выручка_препред'], ax=axes[1, 1], color='orange', label='Не в сегменте')
axes[1, 1].set_title('Распределение дохода')
axes[1, 1].set_xlabel('Выручка')
axes[1, 1].set_ylabel('Плотность')
axes[1, 1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
#
#
# Совет 🤔:
#
#
#
# Графики сравнения построены, но не все удобно анализировать. Например как по твоим графикам понять рассылка больше в твоём сегменте или "все остальные"?

# %% [markdown]
# На основании вышеуказанных выводов предлагается следующая стратегия для увеличения прибыли:
#
# 1. Сосредоточить усилия на заинтересованных пользователях, которые делают больше половины покупок во время акций, принесли выручку выше медианного значения и участвуют в частых коммуникациях. Фокусироваться на этой группе пользователей поможет оптимизировать маркетинговые усилия и повысить вероятность успешных продаж.
#
# 2. Внимательно изучить предпочтения пользователей в категориях товаров. Учитывая, что наиболее популярными категориями являются "мелкая бытовая техника и электроника" и "техника для красоты и здоровья", можно разработать и продвигать новые продукты или предложения в этих категориях. Также стоит проанализировать причины меньшего спроса на детские товары и кухонную утварь, возможно, требуется дополнительная аналитика или корректировка ассортимента.
#
# 3. Усилить маркетинговые усилия по продвижению рассылок. Поскольку большинство сегментируемых пользователей пользуются рассылкой, это представляет возможность увеличить вовлеченность пользователей и стимулировать повторные покупки.
#
# 4. Проанализировать соотношение стандартных и премиум аккаунтов и, при необходимости, скорректировать маркетинговые стратегии для более эффективного привлечения пользователей с премиум аккаунтами.
#
# Так же после сравнительного анализа с покупателями не вошедшими в наш сегмент можно сказать:
#
# 1. Покупатели, не вошедшие в сегмент, могут иметь более разнообразные интересы и предпочтения в выборе товаров. Это может быть связано с различными семейными составами, возрастными группами или жизненными стилями.
#
# 2. Товары для детей и домашний текстиль могут быть связаны с основными потребностями семьи, и покупатели, не вошедшие в сегмент, могут быть более чувствительны к цене и предпочитать экономные варианты.
#
# 3. Маркетинговые усилия могут быть не так успешны в привлечении этих покупателей для покупок в категориях, которые более популярны среди сегментированных покупателей. Возможно, необходимы дополнительные меры для привлечения этой аудитории.

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Успех 👍:
#
#
#
# Звучит неплохо
#
#
#
#
# <div class="alert alert-warning">
#
#
#
# Совет:
#
#
#
#
# В этом разделе студент сам выбирает как проводить сегментацию, но определённые рамки всё-таки существуют (предлагаю ознакомится, и на основе этого попробовать доработать раздел, подняв его на новую высоту)
#
#
#
# - У нас есть файл money, в нем содержится важная информация о прибыльности клиентов. Это наверно самый важный параметр с точки зрения бизнеса: клиент может много покупать, но прибыльность от него будет небольшой, или наоборот клиент может мало покупать, но он покупает товары которые продавать магазину выгодно. Чувствуешь разницу?! Стоит обогатить наши данные этой информацией
#
#
#
# - Используем результаты моделирования, а иначе зачем мы все это делали?!  Можно использовать результат predict_proba посмотрев на уверенность модели в том что клиент снижает активность - вот и вариант сегментации.  Можно использовать модель как источник вдохновения для выбора признаков (если модель считает признак важным для прогноза активности, то логично посмотреть на него поближе). Можно приглядеться на графики shap.beeswarm, увидев там что то интересное. Или можно все это использовать вместе.  Кстати можно подглядеть внутрь моделей не только с помощью shap, но и построить [plot_tree](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html) и там подсмотреть  комбинацию признаков с конкретными порогами, сделав упор на признаки - причины. Например проанализировав   plot_tree мы можем увидеть что для такой то группы товаров, при таком то значении акционных покупок и при таком то сервисе, высока доля не снижающих активность клиентов (ничего такого на самом деле нет, это просто пример). И мы сможем сделать более сложные маркетинговые предложения.
#
#
#
# - Ещё один хороший метод анализа кроме сравнения это отслеживание динамики. Можно посмотреть на динамику выручки по месяцам, в группировке по категориальным признакам (популярная категория, тип сервиса, разрешить сообщить), возможно тут получится увидеть что то интересное и сделать какие то маркетинговые предложения. Отслеживание динамики, как и сравнение, отличный способ найти в данных что то интересное.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Мы успешно завершили первый этап нашего проекта по увеличению прибыли. В ходе работы мы провели сбор данных о клиентах, включая информацию о их поведении, коммуникации и финансовой активности. После этого мы осуществили подготовку данных, включая очистку и кодирование, чтобы быть готовыми к анализу.

# %% [markdown]
# Следующим этапом был анализ данных, где мы изучили основные закономерности и корреляции в поведении наших клиентов. Это позволило нам разработать модель для прогнозирования вероятности снижения покупательской активности в будущем. После тщательной оценки различных моделей, мы выбрали метод опорных векторов (SVC) как наиболее подходящий для наших целей.

# %% [markdown]
# Исходя из результатов нашего анализа и моделирования, мы выделили наиболее заинтересованных клиентов, которые склонны к частым покупкам во время акций, приносят высокую прибыль и активно взаимодействуют с нами. На основе этого мы разработали персонализированные предложения для этой группы клиентов с целью увеличения их покупательской активности.

# %% [markdown]
# Наш следующий шаг - тестирование и оптимизация предложений на выборке клиентов, а также регулярное отслеживание результатов нашей стратегии. Мы уверены, что эти усилия помогут нам не только увеличить прибыль, но и улучшить взаимодействие с нашими клиентами в целом.

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюера</b></font>
#
#
#
# Дмитрий, у тебя старательно выполненная работа, все четко, осмысленно.
#
#
#
# Выводы подробные, в конце разделов есть промежуточные выводы.
#
#
#
#
#
# Я оставил небольшие советы желтым, по желанию можешь воспользоваться, в частности:
#
#
#
# - хорошо бы корреляцию и графики построить в том числе в разбивке по таргету, это хороший подход если мы хотим увидеть что то интересное дополнительно
#
#
#
# - поработать надо оформлением графиков, используя subplots,  seaborn вместо matplotlib
#
#
#
# - вручную закодировать "снизилась" единичкой, или хотя бы сделать проверку.  Это позволит избежать дальнейшей путаницы
#
#
#
# Обязательное к исправлению:
#
#
#
#
#
# - не все графики построены
#
#
#
# - как будто у нас нет мультикорениальности
#
#
#
#
# - LaberelEncoder предполагает какую-то упорядочность в данных, в выбранном тобой категориальном  признака такой упорядоченности нет, а это может стать проблемой для линейной модели
#
#
#
#
#
# - объясняем почему выбрали ту или иную метрику
#
#
#
#
# - нарушена логика использования выборок:  пока не выберем лучшую модель нам валидации  (кроссвалидации), тестовой выборки для нас не существует
#
#
#
#
# - анализируем наш сегмент в сравнении c клиентами не попавших в твой сегмент отличается
#
#
#
#
#
#
# Жду исправлений, для принятия проекта. Если какие то вопросы, то сразу спрашивай )

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV2</b></font>
#
# Спасибо за работу! Написал ещё парочку советов
#
#
# Помню что горишь, тем не менее стоит  доработать графики в разделе "исследование"

# %% [markdown]
# <div class="alert alert-info">
# <font size="5"><b>Комментарий ревьюераV3</b></font>
#
# Спасибо за работу!
#
#
#
# Красного нет, вопросов нет, значит все, пора принимать) Надеюсь мои советы и вопросики были полезны и в копилочку знаний упало что то новое, а проект стал лучше, и симпатичней.
#
#
# Отличная работа Дмитрий. Желаю успехов в дальнейшей учебе!
#
# </div>
